# %% [markdown]
# # Structure gemini outputs in a robust way

# %%
from google import genai


client = genai.Client()

response = client.models.generate_content(
    model="gemini-2.5-flash", contents="""
    List a few asian soups recipes, a yummy description
    and list the ingredients
    """
)
print(response.text)
# Out:
# Oh, the wonderful world of Asian soups! Each one tells a story of culture and flavor. Here are a few to get your taste buds tingling:
#
# ---
#
# ### 1. Vietnamese Pho Bo (Beef Noodle Soup)
#
# **A Yummy Description:**
# Imagine an aromatic embrace – a **fragrant, crystal-clear beef broth** simmered for hours with star anise, cinnamon, ginger, and charred onions. This soul-soothing elixir is poured over **silky-smooth rice noodles**, topped with tender, thinly sliced raw beef (which cooks in the hot broth), and sometimes a scattering of well-done brisket. It's a symphony of subtle sweetness, savory depth, and warmth, eagerly garnished with fresh bean sprouts, fragrant basil, cilantro, lime wedges, and a fiery kick of jalapeño or Sriracha. It's not just a soup; it's a hug in a bowl!
#
# **Ingredients:**
#
# *   **For the Broth:**
#     *   Beef bones (marrow and knuckle bones)
#     *   Beef chuck or brisket (for cooked beef)
#     *   Yellow onions (charred)
#     *   Ginger (charred)
#     *   Star anise
#     *   Cinnamon sticks
#     *   Black cardamom pods
#     *   Cloves
#     *   Fennel seeds
#     *   Coriander seeds
#     *   Fish sauce
#     *   Rock sugar
#     *   Salt
#
# *   **Main Bowl Ingredients:**
#     *   Flat rice noodles (Banh Pho), fresh or dried
#     *   Thinly sliced raw beef (e.g., eye round, sirloin)
#     *   Cooked beef (from the broth, thinly sliced)
#
# *   **Garnishes (Served on the side):**
#     *   Fresh bean sprouts
#     *   Thai basil leaves
#     *   Cilantro (chopped)
#     *   Mint leaves
#     *   Lime wedges
#     *   Thinly sliced jalapeño or serrano peppers
#     *   Hoisin sauce
#     *   Sriracha chili sauce
#
# ---
#
# ### 2. Thai Tom Yum Goong (Spicy Shrimp Soup)
#
# **A Yummy Description:**
# Prepare for an explosion of flavors! Tom Yum Goong is a vibrant, **hot and sour Thai masterpiece** that dances on your palate. Its fragrant broth is infused with the holy trinity of Thai herbs: aromatic lemongrass, pungent galangal, and citrusy kaffir lime leaves. Plump, juicy shrimp swim alongside earthy mushrooms, all brought together with a fiery kiss of bird's eye chilies, a tangy squeeze of lime juice, and a savory hint of fish sauce. It's spicy, refreshing, and utterly addictive, promising an invigorating culinary adventure with every spoonful.
#
# **Ingredients:**
#
# *   **For the Broth & Flavor Base:**
#     *   Chicken or vegetable broth (or water)
#     *   Lemongrass stalks (bruised and sliced)
#     *   Galangal (thinly sliced)
#     *   Kaffir lime leaves (torn)
#     *   Bird's eye chilies (crushed or sliced, adjust to desired heat)
#     *   Thai chili paste (Nam Prik Pao - optional, for color and deeper flavor)
#     *   Fish sauce
#     *   Fresh lime juice
#
# *   **Main Bowl Ingredients:**
#     *   Large shrimp (peeled and deveined)
#     *   Straw mushrooms or oyster mushrooms
#
# *   **Garnishes:**
#     *   Fresh cilantro (chopped)
#     *   Cherry tomatoes (halved, optional)
#
# ---
#
# ### 3. Japanese Miso Soup (Misoshiru)
#
# **A Yummy Description:**
# A gentle, **umami-rich hug in a bowl**, Miso Soup is the quintessential Japanese comfort food. Its warm, savory broth, made from fermented soybean paste (miso) and dashi, offers a depth of flavor that is both simple and profoundly satisfying. Delicate cubes of silken tofu, wisps of rehydrated wakame seaweed, and a sprinkle of vibrant green onions float within, creating a light yet nourishing experience that perfectly complements any meal or serves as a mindful moment of tranquility.
#
# **Ingredients:**
#
# *   **For the Broth (Dashi):**
#     *   Water
#     *   Kombu (dried kelp)
#     *   Bonito flakes (katsuobushi - skip for vegetarian/vegan)
#     *   *Alternatively, instant dashi powder can be used.*
#
# *   **Flavoring:**
#     *   Miso paste (white/shiro miso for a milder flavor, or red/aka miso for stronger)
#
# *   **Main Bowl Ingredients:**
#     *   Silken tofu (cut into small cubes)
#     *   Dried wakame seaweed (rehydrated)
#
# *   **Garnish:**
#     *   Green onions (scallions), thinly sliced
#
# ---
#
# ### 4. Korean Kimchi Jjigae (Kimchi Stew)
#
# **A Yummy Description:**
# Prepare for a **hearty, bubbling pot of spicy, savory, and wonderfully tangy goodness**! Kimchi Jjigae is a beloved Korean staple, bursting with the deep, complex flavors of well-fermented kimchi. Simmered until tender with succulent pieces of pork belly (or tofu for a vegetarian version), garlic, onions, and often gochujang (Korean chili paste), this stew is the ultimate soul-warming comfort food. Served piping hot, often with a side of rice, it's robust, deeply satisfying, and guaranteed to awaken your senses with its vibrant, fiery personality.
#
# **Ingredients:**
#
# *   **Base & Flavoring:**
#     *   Aged kimchi (the older and tangier, the better!)
#     *   Pork belly (sliced into bite-sized pieces) or soft tofu (for vegetarian)
#     *   Onion (sliced)
#     *   Garlic (minced)
#     *   Gochujang (Korean chili paste)
#     *   Gochugaru (Korean chili powder, for extra spice/color)
#     *   Sesame oil
#
# *   **Broth:**
#     *   Anchovy broth (made with dried anchovies and kombu), or plain water/vegetable broth
#
# *   **Main Bowl Ingredients:**
#     *   Soft tofu (sundubu), cut into large chunks
#     *   Green onions (scallions), sliced
#
# *   **Optional Add-ins:**
#     *   Mushrooms (e.g., enoki, shiitake)
#     *   Zucchini slices
#     *   A raw egg (cracked in just before serving, cooks in the hot stew)
#
# ---
#
# Enjoy your delicious culinary journey!

# %%
response = client.models.generate_content(
    model="gemini-2.5-flash", contents="""
    List a few asian soups recipes, a yummy description
    and list the ingredients. Structure it in json format
    """
)
print(response.text)
# Out:
# ```json
# {
#   "asian_soups": [
#     {
#       "name": "Tom Yum Goong (Spicy Thai Shrimp Soup)",
#       "description": "A vibrant and aromatic hot and sour soup from Thailand, bursting with zesty lime, fiery chilies, fragrant lemongrass, galangal, and succulent shrimp. Each spoonful is an exhilarating dance of flavors that awakens your senses and leaves you craving more!",
#       "ingredients": [
#         "2 cups chicken or vegetable broth",
#         "1 lb large shrimp, peeled and deveined",
#         "8 oz straw mushrooms or oyster mushrooms, sliced",
#         "2 stalks lemongrass, bruised and sliced into 1-inch pieces",
#         "1-inch piece galangal, thinly sliced",
#         "4 kaffir lime leaves, torn",
#         "2-4 Thai bird's eye chilies, crushed or sliced (to taste)",
#         "2 tbsp fish sauce",
#         "3 tbsp fresh lime juice",
#         "1 cup cherry tomatoes, halved",
#         "Fresh cilantro, for garnish",
#         "1-2 tsp Thai chili paste (optional, for extra color and heat)"
#       ]
#     },
#     {
#       "name": "Pho Bo (Vietnamese Beef Noodle Soup)",
#       "description": "Vietnam's national dish, a profoundly comforting and aromatic beef noodle soup. Its clear, slow-simmered broth is infused with star anise, cloves, and cinnamon, served over slippery rice noodles, tender slices of rare beef, and a mountain of fresh herbs and sprouts. Pure, soulful deliciousness!",
#       "ingredients": [
#         "2 lbs beef bones (marrow bones, oxtail)",
#         "1 lb beef flank steak or sirloin, thinly sliced",
#         "1 lb fresh flat rice noodles (banh pho)",
#         "1 large onion, halved and charred",
#         "3-inch piece ginger, halved and charred",
#         "5-6 star anise pods",
#         "4-5 cloves",
#         "1 cinnamon stick",
#         "2 tbsp fish sauce",
#         "1 tbsp sugar",
#         "Fresh bean sprouts, for serving",
#         "Fresh Thai basil, for serving",
#         "Fresh cilantro, for serving",
#         "Lime wedges, for serving",
#         "Sliced jalapeños or bird's eye chilies, for serving",
#         "Hoisin sauce, for serving",
#         "Sriracha, for serving"
#       ]
#     },
#     {
#       "name": "Japanese Miso Soup",
#       "description": "A cornerstone of Japanese cuisine, this deceptively simple yet deeply satisfying soup is a warm hug in a bowl. Made from a savory dashi broth infused with umami-rich miso paste, delicate cubes of silken tofu, and tender wakame seaweed. It's light, flavorful, and incredibly comforting.",
#       "ingredients": [
#         "4 cups dashi stock (made from kombu and bonito flakes, or dashi powder)",
#         "4 tbsp miso paste (white or red, to taste)",
#         "4 oz silken tofu, cubed",
#         "2 tbsp dried wakame seaweed, rehydrated and chopped",
#         "2 green onions, thinly sliced (for garnish)"
#       ]
#     },
#     {
#       "name": "Laksa (Malaysian/Singaporean Coconut Curry Noodle Soup)",
#       "description": "A truly indulgent and flavorful street food classic! This vibrant noodle soup features a rich, spicy, and creamy coconut curry broth, often with a hint of seafood. Loaded with various noodles (rice vermicelli and thick wheat noodles), shrimp, fish cakes, bean sprouts, and a squeeze of lime, it’s a symphony of textures and bold flavors.",
#       "ingredients": [
#         "1 can (13.5 oz) coconut milk",
#         "4 cups chicken or seafood broth",
#         "4-6 tbsp laksa paste (store-bought or homemade)",
#         "1 lb mixed noodles (rice vermicelli and thick wheat noodles)",
#         "1/2 lb medium shrimp, peeled and deveined",
#         "4 oz fish cakes or fish balls, sliced",
#         "4 oz tofu puffs (optional)",
#         "1 cup fresh bean sprouts",
#         "2 hard-boiled eggs, halved (for garnish)",
#         "Fresh cilantro, for garnish",
#         "Lime wedges, for serving",
#         "Sambal (chili paste), for serving (optional)"
#       ]
#     }
#   ]
# }
# ```
